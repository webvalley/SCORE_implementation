# %%
import pandas as pd

# %%
filepath='./Data/DBPLIC-1.xls'

# %%
df = pd.read_excel(filepath)

# %%
df['Score']=None

# %%
df[['cod_pz','SCORE']]
# Out:
#       cod_pz SCORE
# 0          1  None
# 1          2  None
# 2          3  None
# 3          4  None
# 4          5  None
# 5          6  None
# 6          7  None
# 7          8  None
# 8          9  None
# 9         10  None
# 10        11  None
# 11        12  None
# 12        13  None
# 13        14  None
# 14        15  None
# 15        16  None
# 16        17  None
# 17        18  None
# 18        19  None
# 19        20  None
# 20        21  None
# 21        22  None
# 22        23  None
# 23        24  None
# 24        25  None
# 25        26  None
# 26        27  None
# 27        28  None
# 28        29  None
# 29        30  None
# ...      ...   ...
# 2576    2577  None
# 2577    2578  None
# 2578    2579  None
# 2579    2580  None
# 2580    2581  None
# 2581    2582  None
# 2582    2583  None
# 2583    2584  None
# 2584    2585  None
# 2585    2586  None
# 2586    2587  None
# 2587    2588  None
# 2588    2589  None
# 2589    2590  None
# 2590    2591  None
# ...

# %%
filepath2='./Data/Milano_Cleaned_wSCORE.xlsx'

# %%
dataMilan = pd.read_excel(filepath2)

# %%
dataMilan = dataMilan[['subject_id','SCORE']][0::4]

# %%
dataMilan.head()
# Out:
#     subject_id      SCORE
# 0           86  18.261460
# 4           33   3.306981
# 8          270   3.875747
# 12          10   2.872045
# 16          31   6.301846

# %%
dataMilan.shape
# Out:
# (1445, 2)

# %%
for index1, row1 in df.iterrows():
    for index2, row2 in dataMilan.iterrows():
        if (row2['subject_id']==row1['cod_pz']):
            df['SCORE'][index1]=row2['SCORE']
            print(index1 , df['SCORE'][index1])
            break;
# Out:
# C:\Users\Giammi\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# 0 2.276227915328533
# 1 0.06478567685963554
# 2 9.269903582881012
# 4 0.09396831220270796
# 7 0.03271150256184407
# 8 0.1146998430597734
# 9 2.872044682068287
# 10 1.743522541305342
# 12 0.07914817646660355
# 14 0.375112754750806
# 16 0.2996000888831118
# 17 3.92345828220958
# 18 0.09957178009333267
# 19 0.6077907259228632
# 20 0.1685320442264882
# 21 1.430843632499257
# 22 7.414665620821226
# 23 0.5967203234332863
# 25 3.416941814844743
# 26 0.994661289833465
# 27 1.669344626065628
# 28 0.3612432760184303
# 29 0.4979546424695891
# 30 6.301846185516602
# 32 3.306980674179061
# 33 9.172036267961847
# 37 0.6911775067570347
# 38 0.3695674700054608
# ...

# %%
df[['cod_pz','SCORE']]
# Out:
#       cod_pz      SCORE
# 0          1    2.27623
# 1          2  0.0647857
# 2          3     9.2699
# 3          4       None
# 4          5  0.0939683
# 5          6       None
# 6          7       None
# 7          8  0.0327115
# 8          9     0.1147
# 9         10    2.87204
# 10        11    1.74352
# 11        12       None
# 12        13  0.0791482
# 13        14       None
# 14        15   0.375113
# 15        16       None
# 16        17     0.2996
# 17        18    3.92346
# 18        19  0.0995718
# 19        20   0.607791
# 20        21   0.168532
# 21        22    1.43084
# 22        23    7.41467
# 23        24    0.59672
# 24        25       None
# 25        26    3.41694
# 26        27   0.994661
# 27        28    1.66934
# 28        29   0.361243
# 29        30   0.497955
# ...      ...        ...
# 2576    2577       None
# 2577    2578       None
# 2578    2579       None
# 2579    2580       None
# 2580    2581       None
# 2581    2582       None
# ...

# %%
filename='./Data/DBPLIC1_wSCORE.xlsx'

# %%
df.to_excel(filename)
